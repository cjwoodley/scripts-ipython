# %%
import pandas as pa
import numpy as np

# %%
df = pa.read_csv("/home/cwoodley/Downloads/data/392532720_82015_577_airline_delay_causes.csv")

# %%
swa_info = df[df['carrier'].str.contains('wn',case=False)]

# %%
print (swa_info)
# Out:
#       year   month carrier            carrier_name airport  \
# 1005  2015       8      WN  Southwest Airlines Co.     LGA
# 1006  2015       8      WN  Southwest Airlines Co.     LIT
# 1007  2015       8      WN  Southwest Airlines Co.     MAF
# 1008  2015       8      WN  Southwest Airlines Co.     CMH
# 1009  2015       8      WN  Southwest Airlines Co.     CRP
# 1010  2015       8      WN  Southwest Airlines Co.     DAL
# 1011  2015       8      WN  Southwest Airlines Co.     DAY
# 1012  2015       8      WN  Southwest Airlines Co.     DCA
# 1013  2015       8      WN  Southwest Airlines Co.     DEN
# 1014  2015       8      WN  Southwest Airlines Co.     DSM
# 1015  2015       8      WN  Southwest Airlines Co.     DTW
# 1016  2015       8      WN  Southwest Airlines Co.     ECP
# 1017  2015       8      WN  Southwest Airlines Co.     ELP
# 1018  2015       8      WN  Southwest Airlines Co.     EWR
# 1019  2015       8      WN  Southwest Airlines Co.     FLL
# ...

# %%
swa_query = df.query('carrier in ("WN")')

# %%
print (swa_query)
# Out:
#       year   month carrier            carrier_name airport  \
# 1005  2015       8      WN  Southwest Airlines Co.     LGA
# 1006  2015       8      WN  Southwest Airlines Co.     LIT
# 1007  2015       8      WN  Southwest Airlines Co.     MAF
# 1008  2015       8      WN  Southwest Airlines Co.     CMH
# 1009  2015       8      WN  Southwest Airlines Co.     CRP
# 1010  2015       8      WN  Southwest Airlines Co.     DAL
# 1011  2015       8      WN  Southwest Airlines Co.     DAY
# 1012  2015       8      WN  Southwest Airlines Co.     DCA
# 1013  2015       8      WN  Southwest Airlines Co.     DEN
# 1014  2015       8      WN  Southwest Airlines Co.     DSM
# 1015  2015       8      WN  Southwest Airlines Co.     DTW
# 1016  2015       8      WN  Southwest Airlines Co.     ECP
# 1017  2015       8      WN  Southwest Airlines Co.     ELP
# 1018  2015       8      WN  Southwest Airlines Co.     EWR
# 1019  2015       8      WN  Southwest Airlines Co.     FLL
# ...
